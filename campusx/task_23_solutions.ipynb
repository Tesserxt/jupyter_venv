# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

plt.style.use('default')

# %% [markdown]
# ## `Problem 1 to 5`:
#
# Dataset link: https://tinyurl.com/2fe6vz4u
#
# **Add a label to every axis and add a proper title for the charts. Also add proper labels if there are multiple representations.** Then, you can customize it as your wish.
#
# ### **`Problem-1:`** Draw a line plot of which, the x-axis is the "Year" and the y-axis is sum of "PM2.5" of two countries Iran and China.

# %%
# code here
df = pd.read_csv('https://tinyurl.com/2fe6vz4u')
df.head()
# Out:
#    Unnamed: 0  Position Country  City/Town  Year  PM2.5 Temporal coverage  \
# 0           0         1   India     Kanpur  2016    173              >75%
# 1           1         2   India  Faridabad  2016    172              >75%
# 2           2         3   India       Gaya  2016    149        50% -< 75%
# 3           3         4   India   Varanasi  2016    146              >75%
# 4           4         5   India      Patna  2016    144              >75%
#
#    PM10 Temporal coverage.1  Database version (year)
# 0   319                 NaN                     2018
# 1   316                 NaN                     2018
# 2   275                 NaN                     2018
# 3   260                 NaN                     2018
# 4   266                 NaN                     2018

# %%
china = df[df['Country'] == 'China']
iran = df[df['Country'] == 'Iran']
iranY = iran.groupby('Year')['PM2.5'].sum()
chinaY = china.groupby('Year')['PM2.5'].sum()
chinaY
# Out:
# Year
# 2014     2725
# 2015      425
# 2016    11106
# Name: PM2.5, dtype: int64

# %%
iranY = df.query('Country == "Iran"').groupby('Year')['PM2.5'].sum()
chinaY = df.query('Country == "China"').groupby('Year')['PM2.5'].sum()

# %%
plt.plot(iranY.index, iranY.values, label='iran')
plt.plot(chinaY.index, chinaY.values, label = 'china')
plt.title('Radhe Radhe')
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.xticks(df['Year'].value_counts().index)

plt.legend()
plt.grid()
plt.show()

# %%
iran_series = df.query('Country == "Iran"').groupby('Year')['PM2.5'].sum()
china_series = df.query('Country == "China"').groupby('Year')['PM2.5'].sum()

# %%
plt.plot(iran_series.index,iran_series.values,label='Iran',linestyle='dashed')
plt.plot(china_series.index,china_series.values,label='China',linestyle='dotted',color='red')
plt.xlabel('Year')
plt.ylabel('PM2.5')
plt.title('PM2.5 Over the years')
plt.xticks(df['Year'].value_counts().index)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-2:`** Draw a histogram of the  column "PM10" of which the y-axis represents the probability (see the documentation how to draw the probability).

# %%
df['PM10']
# Out:
# 0      319
# 1      316
# 2      275
# 3      260
# 4      266
#       ...
# 495     31
# 496     29
# 497     35
# 498     59
# 499     56
# Name: PM10, Length: 500, dtype: int64

# %%
plt.hist(df['PM10'], bins=20, edgecolor='black', color='red', density=True, histtype='barstacked')
plt.xlabel('Bins')
plt.ylabel('probablity')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.normal(0, 1, 10)
print(data)

plt.hist(data, bins=10
         , density=True, alpha=0.6, color='skyblue', edgecolor='black')  # probability density
plt.title("Histogram with density=True")
plt.show()
# Out:
# [ 1.25903722 -1.287836   -0.6679313   0.24359705 -0.38062367  0.54838113
#  -0.46618862 -1.71717487 -1.05644318  1.14113103]

# %%
plt.hist(data, bins=10, alpha=0.6, color='skyblue', edgecolor='black')  # probability density
plt.title("Histogram with density=True")
plt.show()

# %%
# code here
plt.hist(df['PM10'],density=True,bins=50,facecolor='green',alpha=0.6)
plt.xlabel('Bins')
plt.ylabel('Probability')
plt.title('Histogram of PM10')
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-3:`** Draw a scatter plot where x-axis represents "PM2.5" and y-axis represents "PM10" for two countries Poland and Chile.

# %%
poland = df.query('Country == "Poland"')
chile = df.query('Country == "Chile"')
plt.scatter(poland['PM2.5'], poland['PM10'], label='poland')
plt.scatter(chile['PM2.5'], chile['PM10'], label='chile')
plt.xlabel('PM 2.5')
plt.ylabel('PM 10')
plt.title('PM2.5 & PM10 comparision of Chile and POland')
plt.legend()
plt.grid
# Out:
# <function matplotlib.pyplot.grid(visible: 'bool | None' = None, which: "Literal['major', 'minor', 'both']" = 'major', axis: "Literal['both', 'x', 'y']" = 'both', **kwargs) -> 'None'>

# %%
d1 = [1,2,3,4,5,6]
plt.scatter(d1,d1)

# %%
# code here
chile_df = df.query("Country == 'Chile'")
poland_df = df.query("Country == 'Poland'")

# %%
plt.scatter(chile_df['PM2.5'],chile_df['PM10'],marker="+",color='red',label='Chile')
plt.scatter(poland_df['PM2.5'],poland_df['PM10'],marker="D",color='black',label='Poland')
plt.xlabel('PM2.5')
plt.ylabel('PM10')
plt.title('PM2.5 Vs PM10 for Chile and Poland')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### **`Problem-4:`** Draw a pie chart of top 5 most frequent countries.

# %%
top5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 top5
#
# NameError: name 'top5' is not defined

# %%
top5 = df.Country.value_counts().head()
plt.pie(top5, autopct="%0.1f%%", labels=top5.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x77dff5f2b250>,
#   <matplotlib.patches.Wedge at 0x77dff5f2b610>,
#   <matplotlib.patches.Wedge at 0x77dff5f2b9d0>,
#   <matplotlib.patches.Wedge at 0x77dff5f2bd90>,
#   <matplotlib.patches.Wedge at 0x77dff5f5c190>],
#  [Text(-0.6965606869003981, 0.8513537510722823, 'China'),
#   Text(0.15733565544541106, -1.0886898050067169, 'Iran'),
#   Text(0.7429694693660515, -0.8111697526350007, 'India'),
#   Text(1.003228203278195, -0.45114650851713894, 'Chile'),
#   Text(1.0899097532685311, -0.14864968795839972, 'Poland')],
#  [Text(-0.37994219285476255, 0.46437477331215393, '71.8%'),
#   Text(0.08581944842476967, -0.5938308027309364, '10.9%'),
#   Text(0.40525607419966436, -0.44245622871000034, '8.1%'),
#   Text(0.5472153836062881, -0.24607991373662122, '4.8%'),
#   Text(0.5944962290555624, -0.08108164797730892, '4.3%')])

# %%
# code here
freq_ser = df['Country'].value_counts().head()

# %%
plt.pie(freq_ser,labels=freq_ser.index,autopct='%0.1f%%')
plt.show()

# %% [markdown]
# ### **`Problem-5:`** Draw a bar chart which represents the counts of top 5 most frequent countries.

# %%
plt.bar(top5.index, top5.values)
# Out:
# <BarContainer object of 5 artists>

# %%
# code here
plt.bar(freq_ser.index,freq_ser)
plt.xlabel('Country')
plt.ylabel('Frequency Count')
plt.show()

# %% [markdown]
# ##`Problem 6-10`
# Data Set - https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv
#
# This is a Sales data of any company in a Year.
#
#
# ###`Problem-6`
# Show a line plot of Total Profit for each month with below styling.
# * Dotted Line
# * Line Color Blue
# * Show Legend at top left
# * Circle Marker

# %%
# code here
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTJh6X4_mqixWsfK9mgkllGQkKYW9Wj9kOIMGY2uYsWeS8n5np87DO-SDGQWJ1HXEnxiOVFVzYFYEcR/pub?gid=558678488&single=true&output=csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['month_number'], df['total_profit'], marker='o', linestyle='dotted', color='blue', label='radha')
plt.legend(loc='upper right')

# %%
plt.plot(df['month_number'],df['total_profit'],label='Month on month Profit',color='b',marker='o',linestyle='dotted')
plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.title('Company sales profit')
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# ###`Problem-7`
# Show sales of each product in march month as pie chart.
# * Show Percentage value
# * Give Title "Sales in March"
# * Explode ToothPaste with shadow

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
march
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 2             3       2140      1340        4550         9550     3550
#
#    moisturizer  total_units  total_profit
# 2         1340        22470        224700

# %%
products.columns
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %%
march = df.query('month_number == 3')
products = march.iloc[:, 1:7]
products
# plt.pie(products.values[0], labels=products.columns, autopct='%0.1f%%', shadow=True)
plt.pie(products.stack(), labels=products.stack().index.get_level_values(1), autopct='%0.1f%%', explode=[0,0,0.1,0,0,0], shadow=True)
plt.title('Sales in march')
# Out:
# Text(0.5, 1.0, 'Sales in march')

# %%
plt.pie(march.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[196], line 1
# ----> 1 plt.pie(march.values)
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/matplotlib/pyplot.py:3795, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3772 @_copy_docstring_and_deprecators(Axes.pie)
#    3773 def pie(
#    3774     x: ArrayLike,
#    (...)
#    3793     data=None,
#    3794 ) -> tuple[list[Wedge], list[Text]] | tuple[list[Wedge], list[Text], list[Text]]:
# -> 3795     return gca().pie(
#    3796         x,
#    3797         explode=explode,
#    3798         labels=labels,
#    3799         colors=colors,
#    3800         autopct=autopct,
#    3801         pctdistance=pctdistance,
#    3802         shadow=shadow,
#    3803         labeldistance=labeldistance,
#    3804         startangle=startangle,
#    3805         radius=radius,
#    3806         counterclock=counterclock,
#    3807         wedgeprops=wedgeprops,
#    3808         textprops=textprops,
#    3809         center=center,
#    3810         frame=frame,
#    3811         rotatelabels=rotatelabels,
#    3812         normalize=normalize,
#    3813         hatch=hatch,
#    3814         **({"data": data} if data is not None else {}),
#    3815     )
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:3357, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3355 x = np.asarray(x, np.float32)
#    3356 if x.ndim > 1:
# -> 3357     raise ValueError("x must be 1D")
#    3359 if np.any(x < 0):
#    3360     raise ValueError("Wedge sizes 'x' must be non negative values")
#
# ValueError: x must be 1D

# %%
# code here
labels = df[df['month_number'] == 3].iloc[:,1:7].stack().index.get_level_values(1)
values = df[df['month_number'] == 3].iloc[:,1:7].stack().values

# %%
labels
# Out:
# Index(['facecream', 'facewash', 'toothpaste', 'bathingsoap', 'shampoo',
#        'moisturizer'],
#       dtype='object')

# %%
plt.pie(values,labels=labels,autopct='%0.1f%%',explode=[0,0,0.1,0,0,0],shadow=True)
plt.title("Sales in March")
plt.show()

# %% [markdown]
# ###`Problem-8` Multiline Plot of all products sales.
# * Give different styes for each products
# * Add legend at top right

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %%
plt.plot(df['facecream'], label='facecream')
plt.plot(df['facewash'], label='facewash')
plt.plot(df['toothpaste'], label='toothpaste')
plt.plot(df['bathingsoap'], label='bathingsoap')
plt.plot(df['shampoo'], label='shampoo')
plt.plot(df['moisturizer'], label='moisturizer')
plt.legend()
plt.show()

# %%
# code here
monthList  = df['month_number'].tolist()

plt.plot(monthList, df['facecream'],   label = 'Face cream', linestyle='dotted', marker='o', linewidth=3)
plt.plot(monthList, df['toothpaste'], label = 'Tooth Paste', marker='o', linewidth=3)
plt.plot(monthList, df['bathingsoap'], label = 'Bathing Soap', marker='o', linewidth=3)
plt.plot(monthList, df['shampoo'], label = 'Shampoo', linestyle='dashdot', linewidth=3)
plt.plot(monthList, df['moisturizer'], label = 'Moisturizer', marker='o', linewidth=3)
plt.plot(monthList, df['facewash'],   label = 'Face Wash',  linestyle='dashed', linewidth=2)


plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper right')
plt.xticks(monthList)
plt.title('Sales data')
plt.show()

# %% [markdown]
# ###`Problem-9` Show Quarter wise Sales data for all products as multi Bar chart.

# %%
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit       date
# 0          1500        21100        211000 2025-01-01
# 1          1200        18330        183300 2025-02-01
# 2          1340        22470        224700 2025-03-01
# 3          1130        22270        222700 2025-04-01
# 4          1740        20960        209600 2025-05-01
# 5          1555        20140        201400 2025-06-01
# 6          1120        29550        295500 2025-07-01
# 7          1400        36140        361400 2025-08-01
# 8          1780        23400        234000 2025-09-01
# 9          1890        26670        266700 2025-10-01
# 10         2100        41280        412800 2025-11-01
# 11         1760        30020        300200 2025-12-01

# %%
df['date'] = pd.to_datetime(['2025-{}-1'.format(month) for month in df['month_number']])

# %%
qdf = df.groupby(df.date.dt.quarter).sum(numeric_only=True).iloc[:,1:7]
qdf
# Out:
#       facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# date
# 1          7270      4040       14850        24850     6850         4040
# 2          9760      4425       15320        24120     5320         4425
# 3         10220      4300       16740        27040     6740         4300
# 4          7230      5750       23000        38000     6500         5750

# %%
plt.plot(qdf)
# Out:
# [<matplotlib.lines.Line2D at 0x7e78e21fe350>,
#  <matplotlib.lines.Line2D at 0x7e78e21fe490>,
#  <matplotlib.lines.Line2D at 0x7e78e21fe5d0>,
#  <matplotlib.lines.Line2D at 0x7e78e21fe710>,
#  <matplotlib.lines.Line2D at 0x7e78e21fe850>,
#  <matplotlib.lines.Line2D at 0x7e78e21fe990>]

# %%
# code here
df['date'] = pd.to_datetime(['2020-{}-01'.format(month) for month in df['month_number']])

# %%
# Out:
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x77dff2d42900>>

# %%
final_df = df.groupby(df['date'].dt.quarter).agg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 final_df = df.groupby(df['date'].dt.quarter).agg()
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/pandas/core/groupby/generic.py:1422, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1420 @doc(_agg_template_frame, examples=_agg_examples_doc, klass="DataFrame")
#    1421 def aggregate(self, func=None, *args, engine=None, engine_kwargs=None, **kwargs):
# -> 1422     relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    1423     func = maybe_mangle_lambdas(func)
#    1425     if maybe_use_numba(engine):
#    1426         # Not all agg functions support numba, only propagate numba kwargs
#    1427         # if user asks for numba
#
# File ~/AllProjects/jupyter/jupyter_venv/lib/python3.13/site-packages/pandas/core/apply.py:1696, in reconstruct_func(func, **kwargs)
#    1690         raise SpecificationError(
#    1691             "Function names must be unique if there is no new column names "
#    1692             "assigned"
#    1693         )
#    1694     if func is None:
#    1695         # nicer error message
# -> 1696         raise TypeError("Must provide 'func' or tuples of '(column, aggfunc).")
#    1698 if relabeling:
#    1699     # error: Incompatible types in assignment (expression has type
#    1700     # "MutableMapping[Hashable, list[Callable[..., Any] | str]]", variable has type
#    1701     # "Callable[..., Any] | str | list[Callable[..., Any] | str] |
#    1702     # MutableMapping[Hashable, Callable[..., Any] | str | list[Callable[..., Any] |
#    1703     # str]] | None")
#    1704     func, columns, order = normalize_keyword_aggregation(  # type: ignore[assignment]
#    1705         kwargs
#    1706     )
#
# TypeError: Must provide 'func' or tuples of '(column, aggfunc).

# %%
final_df

# %%
i = -1
for col in final_df.columns[1:7]:
  plt.bar(final_df.index + i,final_df[col],width=0.15,label=col)
  i = i - 0.15

plt.xticks(final_df.index-1.4,final_df.index)
plt.xlabel('Product')
plt.ylabel('Sales')
plt.legend()
plt.show()

# %%
final_df.iloc[:,1:7]
# Out:
#       facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer
# date
# 1          7270      4040       14850        24850     6850         4040
# 2          9760      4425       15320        24120     5320         4425
# 3         10220      4300       16740        27040     6740         4300
# 4          7230      5750       23000        38000     6500         5750

# %% [markdown]
# ###`Problem-10` Plot Stacked Bar chart quarter wise for each product.

# %%
# code here
final_df
# Out:
#       month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# date
# 1                6       7270      4040       14850        24850     6850
# 2               15       9760      4425       15320        24120     5320
# 3               24      10220      4300       16740        27040     6740
# 4               33       7230      5750       23000        38000     6500
#
#       moisturizer  total_units  total_profit
# date
# 1            4040        61900        619000
# 2            4425        63370        633700
# 3            4300        89090        890900
# 4            5750        97970        979700

# %%
all_cols = []

for col in final_df.columns[1:7]:
  if len(all_cols) == 0:
    plt.bar(final_df.index,final_df[col],label=col)
  else:
    plt.bar(final_df.index,final_df[col],bottom=sum(all_cols),label=col)
  all_cols.append(final_df[col])

plt.xticks(final_df.index - 0.02, final_df.index)
plt.legend()
plt.show()

# %%
sum(all_cols)
# Out:
# date
# 1    61900
# 2    63370
# 3    69340
# 4    86230
# dtype: int64
